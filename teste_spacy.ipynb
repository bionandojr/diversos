# %%
import pandas as pd
import re
import unicodedata
import spacy

nlp = spacy.load('pt')

def limpaTexto(palavra):
    # unicodedata.normalize transforma um caracter em seu equivalente em latin.
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
    # A combinação de funções join(texto).split() serve pra remover espaços múltiplos entre palavras
    # A função lower() transforma a string em minusculas
    palavraSemAcento = ' '.join((re.sub('[^a-zA-Z0-9\\\]', ' ', palavraSemAcento.lower())).split())
    
    return palavraSemAcento


def tokenPosLemma(parsedData):
    print(parsedData)
    print("A string contem o seguinte número de tokens: ", len(parsedData))
    print('')
    # Recebe um documento parseado com Spacy e exibe seus componentes
    # Mais informações em https://spacy.io/api/token#attributes
    for i, token in enumerate(parsedData):
        print("original          :", token.orth_)
        print("lemma             :", token.lemma_)
        print("POS tag           :", token.pos_, '(', spacy.explain(token.pos_), ')')
        print("----------------------------------------")
    
    print("==================================================================")


def detalharToken(parsedData):
    print(parsedData)
    print("A string contem o seguinte número de tokens: ", len(parsedData))
    print('')
    # Recebe um documento parseado com Spacy e exibe seus componentes
    # Mais informações em https://spacy.io/api/token#attributes
    for i, token in enumerate(parsedData):
        print("original          :", token.orth, token.orth_)
        print("lowercased        :", token.lower, token.lower_)
        print("lemma             :", token.lemma, token.lemma_)
        print("shape             :", token.shape, token.shape_)
        print("POS tag           :", token.pos, token.pos_, '(', spacy.explain(token.pos_), ')')
        print("is out of vocab   :", token.is_oov)
        print("Entity type       :", token.ent_type, token.ent_type_, '(', spacy.explain(token.ent_type_), ')')
        print("norm              :", token.norm, token.norm_)

        print("token tag         :", token.tag, token.tag_, '(', spacy.explain(token.tag_), ')')
        print("token dep         :", token.dep, token.dep_, '(', spacy.explain(token.dep_), ')')
        print("token head text   :", token.head.text, token.head)
        print("token head pos    :", token.head.pos, token.head.pos_, '(', spacy.explain(token.head.pos_), ')')
        print("token head dep    :", token.head.dep, token.head.dep_, '(', spacy.explain(token.head.dep_), ')')
        
        print("prefix            :", token.prefix, token.prefix_)
        print("suffix            :", token.suffix, token.suffix_)
        print("log probability   :", token.prob)
        print("Brown cluster id  :", token.cluster)
        print("----------------------------------------")
    
    print("==================================================================")

    
    

print("Ok")
# Out:
# Ok

# %%
# importando a tabela EVCOM reduzida utilizando Pandas

tbl_evcom = pd.read_csv('evcom-eid_2012dez.txt', sep='\t', encoding = "utf-8")

# removendo colunas vazias

tbl_evcom = tbl_evcom.dropna(axis='columns')

tbl_evcom.info()
tbl_evcom.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11789 entries, 0 to 11788
# Data columns (total 2 columns):
# EID     11789 non-null int64
# COMM    11789 non-null object
# dtypes: int64(1), object(1)
# memory usage: 184.3+ KB
#       EID                                                COMM
# 0  3540036  PÓSTO DE GASOLINA FAM , DA ESTRADA DA RAIZ UMA...
# 1  3540036                   COM O VIGIA DO POSTO DE GASOLINA
# 2  3540037                         NA LANCHONETE CHEFS BURGER
# 3  3540037                                 NO ANTIGO MANMUCHE
# 4  3540037                  CLIENTE CONSUMIU E NAO QUER PAGAR
# 5  3540038  O MESMO ESTÁ EM HONDA CIVIC PRETO E TEM UM GOL...
# 6  3540038                  MORA NA RUA DO REGIONAL DE SAUDE.
# 7  3540038                             O GOL ESTÁ SEGUIND ELE
# 8  3540039  POR TRAS DA ANTIGA VIAÇÃO OESTE, NUMA RESIDENC...
# 9  3540039  ESTAO PROMOVENDO BARULHO NA RUA, ALÉM DE ESTAR...

# %%
tbl_evcom['COMM_nlp'] = tbl_evcom['COMM'].apply(lambda x: nlp(x))
print("ok")
# Out:
# ok

# %%
# Exibindo o detalhamento dos tokens

tbl_evcom['COMM_nlp'].apply(lambda x: detalharToken(x))
# Out:
# PÓSTO DE GASOLINA FAM , DA ESTRADA DA RAIZ UMA PESSOA EM UM VEICULO DISCUTINDO
# A string contem o seguinte número de tokens:  15
#
# original          : 17897280973305331524 PÓSTO
# lowercased        : 10699940397413279279 pósto
# lemma             : 17897280973305331524 PÓSTO
# shape             : 13862804199789047564 XXXX
# POS tag           : 91 NOUN ( noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 10699940397413279279 pósto
# token tag         : 11804970445133802148 <np-idf>|N|M|P|@NPHR ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : PÓSTO PÓSTO
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 11885866056272349740 STO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 7237117249260884669 DE
# lowercased        : 11144093025662894627 de
# lemma             : 7237117249260884669 DE
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 11144093025662894627 de
# token tag         : 5059609321826252789 PRP|@N< ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : GASOLINA GASOLINA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 3929483993944067416 D
# suffix            : 7237117249260884669 DE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9281512737112040876 GASOLINA
# lowercased        : 8292619425569158823 gasolina
# lemma             : 9281512737112040876 GASOLINA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 8292619425569158823 gasolina
# token tag         : 95 PROPN ( proper noun )
# token dep         : 423 nmod ( modifier of nominal )
# token head text   : PÓSTO PÓSTO
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 16829822105563051112 G
# suffix            : 5617738909458923955 INA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 15819920436278953464 FAM
# lowercased        : 17024301373998587589 fam
# lemma             : 15819920436278953464 FAM
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 17024301373998587589 fam
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : FAM FAM
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9148987913859918431 F
# suffix            : 15819920436278953464 FAM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2593208677638477497 ,
# lowercased        : 2593208677638477497 ,
# lemma             : 2593208677638477497 ,
# shape             : 2593208677638477497 ,
# POS tag           : 96 PUNCT ( punctuation )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 2593208677638477497 ,
# token tag         : 9640619182559184816 PU|@PU ( None )
# token dep         : 442 punct ( punctuation )
# token head text   : DA DA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 400 appos ( appositional modifier )
# prefix            : 2593208677638477497 ,
# suffix            : 2593208677638477497 ,
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 8966146952901677752 DA
# lowercased        : 17784187696877778905 da
# lemma             : 8966146952901677752 DA
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 17784187696877778905 da
# token tag         : 3141281819827047433 PROP|M|S|@SUBJ> ( None )
# token dep         : 400 appos ( appositional modifier )
# token head text   : FAM FAM
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3929483993944067416 D
# suffix            : 8966146952901677752 DA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 16616857984675363460 ESTRADA
# lowercased        : 10012124632189478955 estrada
# lemma             : 16616857984675363460 ESTRADA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 10012124632189478955 estrada
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : DA DA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 400 appos ( appositional modifier )
# prefix            : 9391737413944127320 E
# suffix            : 6899527908362617990 ADA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 8966146952901677752 DA
# lowercased        : 17784187696877778905 da
# lemma             : 8966146952901677752 DA
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 17784187696877778905 da
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : DA DA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 400 appos ( appositional modifier )
# prefix            : 3929483993944067416 D
# suffix            : 8966146952901677752 DA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 8047291442244588490 RAIZ
# lowercased        : 12433234935593737102 raiz
# lemma             : 8047291442244588490 RAIZ
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 12433234935593737102 raiz
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : DA DA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 400 appos ( appositional modifier )
# prefix            : 16337536289976144572 R
# suffix            : 16991247458343711003 AIZ
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9835091107235309092 UMA
# lowercased        : 11582075131687598139 uma
# lemma             : 9835091107235309092 UMA
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 11582075131687598139 uma
# token tag         : 95 PROPN ( proper noun )
# token dep         : 412 det ( determiner )
# token head text   : PESSOA PESSOA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 8804677687338025421 U
# suffix            : 9835091107235309092 UMA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 5415062119318976503 PESSOA
# lowercased        : 5287207483249078154 pessoa
# lemma             : 5415062119318976503 PESSOA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 5287207483249078154 pessoa
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : PESSOA PESSOA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 2111856556522378306 SOA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2147292570107564507 EM
# lowercased        : 4478690315169353386 em
# lemma             : 2147292570107564507 EM
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 4478690315169353386 em
# token tag         : 5059609321826252789 PRP|@N< ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : VEICULO VEICULO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 9391737413944127320 E
# suffix            : 2147292570107564507 EM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6232330534062966760 UM
# lowercased        : 13153274011942891345 um
# lemma             : 6232330534062966760 UM
# shape             : 14968597813295776895 XX
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 383 LOC ( Non-GPE locations, mountain ranges, bodies of water )
# norm              : 13153274011942891345 um
# token tag         : 8960255933746134731 <-sam>|<arti>|ART|M|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : VEICULO VEICULO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 8804677687338025421 U
# suffix            : 6232330534062966760 UM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2841682844913347579 VEICULO
# lowercased        : 15201912437930522398 veiculo
# lemma             : 2841682844913347579 VEICULO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 383 LOC ( Non-GPE locations, mountain ranges, bodies of water )
# norm              : 15201912437930522398 veiculo
# token tag         : 95 PROPN ( proper noun )
# token dep         : 423 nmod ( modifier of nominal )
# token head text   : PESSOA PESSOA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10926178514336144719 V
# suffix            : 6668503212569505239 ULO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 958180987992020459 DISCUTINDO
# lowercased        : 9727740777468311348 discutindo
# lemma             : 958180987992020459 DISCUTINDO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 383 LOC ( Non-GPE locations, mountain ranges, bodies of water )
# norm              : 9727740777468311348 discutindo
# token tag         : 15030182561273398385 PROP|@N< ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : VEICULO VEICULO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 3929483993944067416 D
# suffix            : 11133415823283406713 NDO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# COM O VIGIA DO POSTO DE GASOLINA
# A string contem o seguinte número de tokens:  7
#
# original          : 13215174042072604852 COM
# lowercased        : 15609295637765553343 com
# lemma             : 13215174042072604852 COM
# shape             : 3552942401566437853 XXX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 15609295637765553343 com
# token tag         : 11880712477874492725 PRP|@ADVL> ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 149303876845869574 C
# suffix            : 13215174042072604852 COM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 17427324969254097257 O
# lowercased        : 1489474827855109852 o
# lemma             : 17427324969254097257 O
# shape             : 100 X
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1489474827855109852 o
# token tag         : 7116197739833909124 <artd>|ART|M|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17427324969254097257 O
# suffix            : 17427324969254097257 O
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 15468836120943621067 VIGIA
# lowercased        : 13640200829493197136 vigia
# lemma             : 15468836120943621067 VIGIA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 13640200829493197136 vigia
# token tag         : 5131677551973564364 PROP|M|S|@P< ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10926178514336144719 V
# suffix            : 13603236538524439169 GIA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 13999379822804992547 DO
# lowercased        : 2158845516055552166 do
# lemma             : 13999379822804992547 DO
# shape             : 14968597813295776895 XX
# POS tag           : 91 NOUN ( noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 2158845516055552166 do
# token tag         : 11377445011298657937 <np-idf>|N|M|S|@N< ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3929483993944067416 D
# suffix            : 13999379822804992547 DO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 385212250301876974 POSTO
# lowercased        : 6771605811855794776 posto
# lemma             : 385212250301876974 POSTO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 6771605811855794776 posto
# token tag         : 15030182561273398385 PROP|@N< ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 11885866056272349740 STO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 7237117249260884669 DE
# lowercased        : 11144093025662894627 de
# lemma             : 7237117249260884669 DE
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 11144093025662894627 de
# token tag         : 5059609321826252789 PRP|@N< ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : GASOLINA GASOLINA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 3929483993944067416 D
# suffix            : 7237117249260884669 DE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9281512737112040876 GASOLINA
# lowercased        : 8292619425569158823 gasolina
# lemma             : 9281512737112040876 GASOLINA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 8292619425569158823 gasolina
# token tag         : 15019192042351174229 PROP|M/F|S|@P< ( None )
# token dep         : 423 nmod ( modifier of nominal )
# token head text   : VIGIA VIGIA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 16829822105563051112 G
# suffix            : 5617738909458923955 INA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# NA LANCHONETE CHEFS BURGER
# A string contem o seguinte número de tokens:  4
#
# original          : 8296308445288022419 NA
# lowercased        : 15286517567172306717 na
# lemma             : 8296308445288022419 NA
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 15286517567172306717 na
# token tag         : 3141281819827047433 PROP|M|S|@SUBJ> ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : NA NA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10850957288794122991 N
# suffix            : 8296308445288022419 NA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 185604115113126005 LANCHONETE
# lowercased        : 17121488141375541150 lanchonete
# lemma             : 185604115113126005 LANCHONETE
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 17121488141375541150 lanchonete
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : NA NA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10603054956214495369 L
# suffix            : 1346004612215239887 ETE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 10264660151342678426 CHEFS
# lowercased        : 2232168887756010308 chefs
# lemma             : 10264660151342678426 CHEFS
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 2232168887756010308 chefs
# token tag         : 3846209355088751346 PROP|M|S|@N<PRED ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : NA NA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 149303876845869574 C
# suffix            : 635781145296030182 EFS
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 1878014134097409997 BURGER
# lowercased        : 14499887322688205112 burger
# lemma             : 1878014134097409997 BURGER
# shape             : 13862804199789047564 XXXX
# POS tag           : 91 NOUN ( noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 14499887322688205112 burger
# token tag         : 5970495103847185396 <np-idf>|N|M|S|@NPHR ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : NA NA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 14230521632333904559 B
# suffix            : 13854892257224012132 GER
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# NO ANTIGO MANMUCHE
# A string contem o seguinte número de tokens:  3
#
# original          : 18406136749522707488 NO
# lowercased        : 13055779130471031426 no
# lemma             : 18406136749522707488 NO
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 13055779130471031426 no
# token tag         : 11907965271786371804 PROP|M|S|@UTT ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : NO NO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10850957288794122991 N
# suffix            : 18406136749522707488 NO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2251790978713065738 ANTIGO
# lowercased        : 10120920509312670926 antigo
# lemma             : 2251790978713065738 ANTIGO
# shape             : 13862804199789047564 XXXX
# POS tag           : 83 ADJ ( adjective )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 10120920509312670926 antigo
# token tag         : 8253533711849070696 ADJ|M|S|@>N ( None )
# token dep         : 399 amod ( adjectival modifier )
# token head text   : MANMUCHE MANMUCHE
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 423 nmod ( modifier of nominal )
# prefix            : 14862748245026736845 A
# suffix            : 7198522531622108547 IGO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 13816138841893234943 MANMUCHE
# lowercased        : 2577203051041639130 manmuche
# lemma             : 13816138841893234943 MANMUCHE
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 2577203051041639130 manmuche
# token tag         : 17451588732518274410 PROP|M|S|@APP ( None )
# token dep         : 423 nmod ( modifier of nominal )
# token head text   : NO NO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3209455878668673793 M
# suffix            : 10013600602455226380 CHE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# CLIENTE CONSUMIU E NAO QUER PAGAR
# A string contem o seguinte número de tokens:  6
#
# original          : 9783068291551071120 CLIENTE
# lowercased        : 4535514403547090944 cliente
# lemma             : 9783068291551071120 CLIENTE
# shape             : 13862804199789047564 XXXX
# POS tag           : 91 NOUN ( noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 4535514403547090944 cliente
# token tag         : 5970495103847185396 <np-idf>|N|M|S|@NPHR ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : CLIENTE CLIENTE
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 149303876845869574 C
# suffix            : 7521366186356408334 NTE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6525559780676999528 CONSUMIU
# lowercased        : 16327169709219857317 consumiu
# lemma             : 6525559780676999528 CONSUMIU
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 16327169709219857317 consumiu
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : CLIENTE CLIENTE
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 149303876845869574 C
# suffix            : 18260456765202999429 MIU
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9391737413944127320 E
# lowercased        : 1720370409040345145 e
# lemma             : 9391737413944127320 E
# shape             : 100 X
# POS tag           : 96 PUNCT ( punctuation )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1720370409040345145 e
# token tag         : 110345372527689653 KC|@CO ( None )
# token dep         : 404 cc ( coordinating conjunction )
# token head text   : NAO NAO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9391737413944127320 E
# suffix            : 9391737413944127320 E
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 3866846631981060773 NAO
# lowercased        : 5579127228874873826 nao
# lemma             : 3866846631981060773 NAO
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 5579127228874873826 nao
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : NAO NAO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10850957288794122991 N
# suffix            : 3866846631981060773 NAO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 14242899850334315809 QUER
# lowercased        : 6559825691931943498 quer
# lemma             : 14242899850334315809 QUER
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 6559825691931943498 quer
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : NAO NAO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 8235454673289795724 Q
# suffix            : 11522938187293562343 UER
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6184348931205881646 PAGAR
# lowercased        : 5045894621619045721 pagar
# lemma             : 6184348931205881646 PAGAR
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 5045894621619045721 pagar
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : NAO NAO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 5801922956700358066 GAR
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# O MESMO ESTÁ EM HONDA CIVIC PRETO E TEM UM GOL BRANCO SEGUNDO O MESMO A VITIMA
# A string contem o seguinte número de tokens:  17
#
# original          : 17427324969254097257 O
# lowercased        : 1489474827855109852 o
# lemma             : 17427324969254097257 O
# shape             : 100 X
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1489474827855109852 o
# token tag         : 7116197739833909124 <artd>|ART|M|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : MESMO MESMO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 426 nsubj ( nominal subject )
# prefix            : 17427324969254097257 O
# suffix            : 17427324969254097257 O
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6953503086702651517 MESMO
# lowercased        : 9755195286912878988 mesmo
# lemma             : 6953503086702651517 MESMO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 9755195286912878988 mesmo
# token tag         : 3141281819827047433 PROP|M|S|@SUBJ> ( None )
# token dep         : 426 nsubj ( nominal subject )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3209455878668673793 M
# suffix            : 18310250568244538183 SMO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 17661113607901381541 ESTÁ
# lowercased        : 4858725201161983290 está
# lemma             : 17661113607901381541 ESTÁ
# shape             : 13862804199789047564 XXXX
# POS tag           : 99 VERB ( verb )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 4858725201161983290 está
# token tag         : 835384283694040431 <mv>|V|PR|3S|IND|@FS-STA ( None )
# token dep         : 408 cop ( copula )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9391737413944127320 E
# suffix            : 13034072436602142279 STÁ
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2147292570107564507 EM
# lowercased        : 4478690315169353386 em
# lemma             : 2147292570107564507 EM
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 4478690315169353386 em
# token tag         : 5218757597609270386 <first-cjt>|PRP|@<PIV ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9391737413944127320 E
# suffix            : 2147292570107564507 EM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 4766069520667797559 HONDA
# lowercased        : 6589987417955505267 honda
# lemma             : 4766069520667797559 HONDA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 6589987417955505267 honda
# token tag         : 95 PROPN ( proper noun )
# token dep         : 399 amod ( adjectival modifier )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9350754067018752509 H
# suffix            : 502964058876851912 NDA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 1964515408030069874 CIVIC
# lowercased        : 18384298635725333164 civic
# lemma             : 1964515408030069874 CIVIC
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 383 LOC ( Non-GPE locations, mountain ranges, bodies of water )
# norm              : 18384298635725333164 civic
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 149303876845869574 C
# suffix            : 8891960909312793118 VIC
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 1468626968074389676 PRETO
# lowercased        : 15840554657788064914 preto
# lemma             : 1468626968074389676 PRETO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 383 LOC ( Non-GPE locations, mountain ranges, bodies of water )
# norm              : 15840554657788064914 preto
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : CIVIC CIVIC
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 14729077102393099397 ETO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9391737413944127320 E
# lowercased        : 1720370409040345145 e
# lemma             : 9391737413944127320 E
# shape             : 100 X
# POS tag           : 96 PUNCT ( punctuation )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1720370409040345145 e
# token tag         : 110345372527689653 KC|@CO ( None )
# token dep         : 404 cc ( coordinating conjunction )
# token head text   : TEM TEM
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9391737413944127320 E
# suffix            : 9391737413944127320 E
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 13162496787778715491 TEM
# lowercased        : 16982568968816499832 tem
# lemma             : 13162496787778715491 TEM
# shape             : 3552942401566437853 XXX
# POS tag           : 99 VERB ( verb )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 16982568968816499832 tem
# token tag         : 835384283694040431 <mv>|V|PR|3S|IND|@FS-STA ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : TEM TEM
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 5582244037879929967 T
# suffix            : 13162496787778715491 TEM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6232330534062966760 UM
# lowercased        : 13153274011942891345 um
# lemma             : 6232330534062966760 UM
# shape             : 14968597813295776895 XX
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 13153274011942891345 um
# token tag         : 15578241951484533351 <arti>|ART|M|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : GOL GOL
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 431 obj ( object )
# prefix            : 8804677687338025421 U
# suffix            : 6232330534062966760 UM
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 12583795238779214915 GOL
# lowercased        : 9693171724593169178 gol
# lemma             : 12583795238779214915 GOL
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 9693171724593169178 gol
# token tag         : 6619028368955408283 PROP|M|S|@<ACC ( None )
# token dep         : 431 obj ( object )
# token head text   : TEM TEM
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 16829822105563051112 G
# suffix            : 12583795238779214915 GOL
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 15295840693357962994 BRANCO
# lowercased        : 2541098600790560144 branco
# lemma             : 15295840693357962994 BRANCO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 2541098600790560144 branco
# token tag         : 15030182561273398385 PROP|@N< ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : BRANCO BRANCO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 14230521632333904559 B
# suffix            : 14291918263881420930 NCO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 8502951096053515549 SEGUNDO
# lowercased        : 8839963191358427389 segundo
# lemma             : 8502951096053515549 SEGUNDO
# shape             : 13862804199789047564 XXXX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 8839963191358427389 segundo
# token tag         : 11880712477874492725 PRP|@ADVL> ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : MESMO MESMO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 12290980237632234855 S
# suffix            : 11133415823283406713 NDO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 17427324969254097257 O
# lowercased        : 1489474827855109852 o
# lemma             : 17427324969254097257 O
# shape             : 100 X
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1489474827855109852 o
# token tag         : 7116197739833909124 <artd>|ART|M|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : MESMO MESMO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17427324969254097257 O
# suffix            : 17427324969254097257 O
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6953503086702651517 MESMO
# lowercased        : 9755195286912878988 mesmo
# lemma             : 6953503086702651517 MESMO
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 9755195286912878988 mesmo
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : MESMO MESMO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3209455878668673793 M
# suffix            : 18310250568244538183 SMO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 14862748245026736845 A
# lowercased        : 11901859001352538922 a
# lemma             : 14862748245026736845 A
# shape             : 100 X
# POS tag           : 89 DET ( determiner )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 11901859001352538922 a
# token tag         : 6291118971016310437 <artd>|ART|F|S|@>N ( None )
# token dep         : 412 det ( determiner )
# token head text   : VITIMA VITIMA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 14862748245026736845 A
# suffix            : 14862748245026736845 A
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 14902577429565117344 VITIMA
# lowercased        : 17677229844010857107 vitima
# lemma             : 14902577429565117344 VITIMA
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 17677229844010857107 vitima
# token tag         : 9934347423089200182 PROP|F|S|@SUBJ> ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : VITIMA VITIMA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10926178514336144719 V
# suffix            : 14177939962186218302 IMA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# ==================================================================
# MORA NA RUA DO REGIONAL DE SAUDE.
# A string contem o seguinte número de tokens:  8
#
# original          : 8001788865247013524 MORA
# lowercased        : 9817417067485075352 mora
# lemma             : 8001788865247013524 MORA
# shape             : 13862804199789047564 XXXX
# POS tag           : 99 VERB ( verb )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 9817417067485075352 mora
# token tag         : 835384283694040431 <mv>|V|PR|3S|IND|@FS-STA ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : MORA MORA
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 3209455878668673793 M
# suffix            : 3673943858780132798 ORA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 8296308445288022419 NA
# lowercased        : 15286517567172306717 na
# lemma             : 8296308445288022419 NA
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 15286517567172306717 na
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : MORA MORA
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 10850957288794122991 N
# suffix            : 8296308445288022419 NA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 2358105587166128578 RUA
# lowercased        : 8660285228906848988 rua
# lemma             : 2358105587166128578 RUA
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 8660285228906848988 rua
# token tag         : 16171551269281556758 PROP|F|S|@NPHR ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : MORA MORA
# token head pos    : 99 VERB ( verb )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 16337536289976144572 R
# suffix            : 2358105587166128578 RUA
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 13999379822804992547 DO
# lowercased        : 2158845516055552166 do
# lemma             : 13999379822804992547 DO
# shape             : 14968597813295776895 XX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 2158845516055552166 do
# token tag         : 15030182561273398385 PROP|@N< ( None )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : RUA RUA
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 17772752594865228322 flat:name ( None )
# prefix            : 3929483993944067416 D
# suffix            : 13999379822804992547 DO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 11840441040650396964 REGIONAL
# lowercased        : 18277008947334407378 regional
# lemma             : 11840441040650396964 REGIONAL
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 18277008947334407378 regional
# token tag         : 15030182561273398385 PROP|@N< ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : REGIONAL REGIONAL
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 16337536289976144572 R
# suffix            : 8737070645367512067 NAL
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 7237117249260884669 DE
# lowercased        : 11144093025662894627 de
# lemma             : 7237117249260884669 DE
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 11144093025662894627 de
# token tag         : 5059609321826252789 PRP|@N< ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : SAUDE SAUDE
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 432 obl ( oblique nominal )
# prefix            : 3929483993944067416 D
# suffix            : 7237117249260884669 DE
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 956963844942986292 SAUDE
# lowercased        : 6052121429657491765 saude
# lemma             : 956963844942986292 SAUDE
# shape             : 13862804199789047564 XXXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 7654241940133152407 MISC ( Miscellaneous entities, e.g. events, nationalities, products or works of art )
# norm              : 6052121429657491765 saude
# token tag         : 3616482297399708784 PROP|@P< ( None )
# token dep         : 432 obl ( oblique nominal )
# prefix            : 3929483993944067416 D
# suffix            : 13999379822804992547 DO
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 6170968282688120269 SOL
# lowercased        : 8338881580749099160 sol
# lemma             : 6170968282688120269 SOL
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 8338881580749099160 sol
# token tag         : 95 PROPN ( proper noun )
# token dep         : 17772752594865228322 flat:name ( None )
# token head text   : DO DO
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 12290980237632234855 S
# suffix            : 6170968282688120269 SOL
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9391737413944127320 E
# lowercased        : 1720370409040345145 e
# lemma             : 9391737413944127320 E
# shape             : 100 X
# POS tag           : 96 PUNCT ( punctuation )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 1720370409040345145 e
# token tag         : 110345372527689653 KC|@CO ( None )
# token dep         : 404 cc ( coordinating conjunction )
# token head text   : TRAS TRAS
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 9391737413944127320 E
# suffix            : 9391737413944127320 E
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 9286603626694575371 POR
# lowercased        : 18244196334509357400 por
# lemma             : 9286603626694575371 POR
# shape             : 3552942401566437853 XXX
# POS tag           : 95 PROPN ( proper noun )
# is out of vocab   : True
# Entity type       : 0  ( None )
# norm              : 18244196334509357400 por
# token tag         : 95 PROPN ( proper noun )
# token dep         : 8110129090154140942 case ( None )
# token head text   : TRAS TRAS
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 17714545831559622561 P
# suffix            : 9286603626694575371 POR
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 5533967619108074207 TRAS
# lowercased        : 12465099835422794330 tras
# lemma             : 5533967619108074207 TRAS
# shape             : 13862804199789047564 XXXX
# POS tag           : 91 NOUN ( noun )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 12465099835422794330 tras
# token tag         : 6548211264875655323 N|@P< ( None )
# token dep         : 8206900633647566924 ROOT ( None )
# token head text   : TRAS TRAS
# token head pos    : 91 NOUN ( noun )
# token head dep    : 8206900633647566924 ROOT ( None )
# prefix            : 5582244037879929967 T
# suffix            : 18014000708025256267 RAS
# log probability   : -20.0
# Brown cluster id  : 0
# ----------------------------------------
# original          : 7237117249260884669 DE
# lowercased        : 11144093025662894627 de
# lemma             : 7237117249260884669 DE
# shape             : 14968597813295776895 XX
# POS tag           : 84 ADP ( adposition )
# is out of vocab   : True
# Entity type       : 381 ORG ( Companies, agencies, institutions, etc. )
# norm              : 11144093025662894627 de
# token tag         : 5059609321826252789 PRP|@N< ( None )
# token dep         : 8110129090154140942 case ( None )
# token head text   : UM UM
# token head pos    : 95 PROPN ( proper noun )
# token head dep    : 432 obl ( oblique nominal )
# prefix            : 3929483993944067416 D
# suffix            : 7237117249260884669 DE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f77e95242ee7> in <module>()
#       1 # Exibindo o detalhamento dos tokens
#       2
# ----> 3 tbl_evcom['COMM_nlp'].apply(lambda x: detalharToken(x))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-4-f77e95242ee7> in <lambda>(x)
#       1 # Exibindo o detalhamento dos tokens
#       2
# ----> 3 tbl_evcom['COMM_nlp'].apply(lambda x: detalharToken(x))
#
# <ipython-input-1-aa0088810894> in detalharToken(parsedData)
#      57
#      58         print("prefix            :", token.prefix, token.prefix_)
# ---> 59         print("suffix            :", token.suffix, token.suffix_)
#      60         print("log probability   :", token.prob)
#      61         print("Brown cluster id  :", token.cluster)
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
