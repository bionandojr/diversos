# %%
import pandas as pd
import cx_Oracle
import re
import unicodedata
import spacy

nlp = spacy.load('pt')

def limpaTexto(palavra):
    # unicodedata.normalize transforma um caracter em seu equivalente em latin.
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
    # A combinação de funções join(texto).split() serve pra remover espaços múltiplos entre palavras
    # A função lower() transforma a string em minusculas
    palavraSemAcento = ' '.join((re.sub('[^a-zA-Z0-9\\\]', ' ', palavraSemAcento.lower())).split())
    
    return palavraSemAcento


def tokenPosLemma(parsedData):
    print(parsedData)
    print("A string contem o seguinte número de tokens: ", len(parsedData))
    print('')
    # Recebe um documento parseado com Spacy e exibe seus componentes
    # Mais informações em https://spacy.io/api/token#attributes
    for i, token in enumerate(parsedData):
        print("original          :", token.orth_)
        print("lemma             :", token.lemma_)
        print("POS tag           :", token.pos_, '(', spacy.explain(token.pos_), ')')
        print("----------------------------------------")
    
    print("==================================================================")


def detalharToken(parsedData):
    print(parsedData)
    print("A string contem o seguinte número de tokens: ", len(parsedData))
    print('')
    # Recebe um documento parseado com Spacy e exibe seus componentes
    # Mais informações em https://spacy.io/api/token#attributes
    for i, token in enumerate(parsedData):
        print("original          :", token.orth, token.orth_)
        print("lowercased        :", token.lower, token.lower_)
        print("lemma             :", token.lemma, token.lemma_)
        print("shape             :", token.shape, token.shape_)
        print("POS tag           :", token.pos, token.pos_, '(', spacy.explain(token.pos_), ')')
        print("is out of vocab   :", token.is_oov)
        print("Entity type       :", token.ent_type, token.ent_type_, '(', spacy.explain(token.ent_type_), ')')
        print("norm              :", token.norm, token.norm_)

        print("token tag         :", token.tag, token.tag_, '(', spacy.explain(token.tag_), ')')
        print("token dep         :", token.dep, token.dep_, '(', spacy.explain(token.dep_), ')')
        print("token head text   :", token.head.text, token.head)
        print("token head pos    :", token.head.pos, token.head.pos_, '(', spacy.explain(token.head.pos_), ')')
        print("token head dep    :", token.head.dep, token.head.dep_, '(', spacy.explain(token.head.dep_), ')')
        
        print("prefix            :", token.prefix, token.prefix_)
        print("suffix            :", token.suffix, token.suffix_)
        print("log probability   :", token.prob)
        print("Brown cluster id  :", token.cluster)
        print("----------------------------------------")
    
    print("==================================================================")

    
    

print(cx_Oracle.clientversion())
# Out:
# (18, 3, 0, 0, 0)

# %%
# Connect as user "hr" with password "welcome" to the "oraclepdb" service running on this computer.
connection = cx_Oracle.connect("MOSSORO", "MOSSORO", "10.0.0.7/cad80.world", encoding = "UTF-8", nencoding = "UTF-8")

print(connection.encoding)

# Registros de EVCOM entre 23 e 26 de dezembro de 2012

# Foram removidos os registros iniciando com **, que em sua maioria constituem mensagens
# de sistema
sql_evcom_mini = """select eid, cpers, comm from evcom 
                    where cdts between '20121223000000HS' and '20121226235959HS'
                        and comm not like '%** %'
                    order by eid, cdts, lin_grp, lin_ord
                 """


sql_event_mini = """select eid, cdts, clname, clrnum, efeatyp, efeanme, cstr_add, estnum, cpers,
                        loc_com, bairro, emun, x_cord/100 as x_cord, y_cord/100 as y_cord
                    from event
                    where curent ='T' and cdts between '20121223000000HS' and '20121226235959HS'
                    order by eid
                 """


tbl_evcom = pd.read_sql(sql_evcom_mini, connection)
tbl_event = pd.read_sql(sql_event_mini, connection)

connection.close()
# Out:
# UTF-8

# %%
tbl_event
# Out:
#          EID              CDTS                       CLNAME          CLRNUM  \
# 0    3542434  20121223000308HS                      EDUARDO        94325507
# 1    3542435  20121223000627HS               MAE Da criança         -------
# 2    3542436  20121223001244HS                        ELANE          ------
# 3    3542437  20121223002255HS                         None            None
# 4    3542438  20121223004631HS                       CLEIDE            None
# 5    3542439  20121223005506HS                       JUNIOR        94127434
# 6    3542440  20121223010610HS               JOÃO MARCELINO            None
# 7    3542441  20121223011045HS                        JÚLIO            None
# 8    3542442  20121223011927HS        JOSÉ RILTON FERNANDES            None
# 9    3542443  20121223012914HS                       HUDSON            None
# 10   3542444  20121223013551HS              AERTIANE - SAMU            None
# 11   3542445  20121223013852HS                        TIAGO            None
# 12   3542446  20121223015739HS                JOSÉ IDAILSON            None
# 13   3542447  20121223020207HS                       FÁTIMA            None
# 14   3542448  20121223020622HS                       VICTOR            None
# 15   3542449  20121223021034HS                         RUAN            None
# 16   3542450  20121223022751HS                        JÂNIO            None
# 17   3542451  20121223023105HS            AMANDA DE FREITAS            None
# 18   3542452  20121223024440HS             MARLENE MEDEIROS            None
# 19   3542453  20121223024805HS      TIAGO DE SOUZA PIMENTEL            None
# 20   3542454  20121223031844HS                    POPULARES            None
# 21   3542455  20121223025651HS                 LÚCIA ARAÚJO            None
# 22   3542456  20121223025810HS                       JUNIOR            None
# 23   3542457  20121223030514HS               MARCELO CARLOS            None
# 24   3542458  20121223032032HS             ANTONIO JERONIMO            None
# 25   3542459  20121223033033HS                        NILDO            None
# 26   3542460  20121223034418HS                    FERNANDES         -------
# 27   3542461  20121223034958HS                        LUCIA            None
# 28   3542462  20121223035533HS                     MARLEIDE        88820770
# 29   3542463  20121223055017HS                        KATIA            None
# ..       ...               ...                          ...             ...
# 435  3542869  20121226190824HS               FLAVIA MARTINS            None
# 436  3542870  20121226191452HS              VALDECIA DANTAS            None
# 437  3542871  20121226192122HS                      JHONATA        99621411
# 438  3542872  20121226192438HS  LUIS CARLOS SOARES DA SILVA            None
# 439  3542873  20121226195803HS                      MAXWELL        87396756
# 440  3542874  20121226195935HS                   jose maria  11111111111111
# 441  3542875  20121226203043HS             VAGNER FERNANDES            None
# 442  3542876  20121226210144HS                    ANTONIMAR        99925502
# 443  3542877  20121226210441HS                CARLOS JUNIOR            None
# 444  3542878  20121226211255HS      CARLOS ANTONIO DA SILVA            None
# 445  3542879  20121226212107HS             BENEDIDA BATISTA            None
# 446  3542880  20121226212658HS                      POPULAR  11111111111111
# 447  3542881  20121226212755HS                         ÊIDO        96080347
# 448  3542882  20121226213241HS  DEIVISSON MENDONÇA DA SILVA        96325151
# 449  3542883  20121226220021HS                   JOAO PAULO        91309712
# 450  3542884  20121226214840HS                     SD FABIO            None
# 451  3542885  20121226214841HS                      POPULAR       9129-3478
# 452  3542886  20121226215252HS     RAIMUNDA NONATA DA SILVA            None
# 453  3542887  20121226215344HS                      POPULAR     11111111111
# 454  3542888  20121226220827HS              ALEXANDRE COSTA        88181422
# 455  3542889  20121226221525HS               CLAUDIA REGINA        96405207
# 456  3542890  20121226222325HS                   ELISANGELA        96120317
# 457  3542891  20121226223050HS              CESAR SEBASTIAO            None
# 458  3542892  20121226232205HS                       CARLOS       9811-5441
# 459  3542893  20121226224726HS                         DEDÉ  **************
# 460  3542894  20121226225149HS                   MAX WENDIO            None
# 461  3542895  20121226230352HS              LUIZ ALCANTAQRA        99945204
# 462  3542896  20121226230447HS      MARIA DISSE DE CARVALHO            None
# 463  3542897  20121226233303HS              RAFAEL PRAXEDES        96914446
# 464  3542898  20121226233703HS               MARIANA DANTAS        99519486
#
#       EFEATYP                             EFEANME               CSTR_ADD  \
# 0        None                    FAZENDA SAO JOAO                   None
# 1         RUA                         JOANA D'ARC                   None
# 2         RUA                        CELINA VIANA                   None
# 3        None            LORIVAL CAETANO FERREIRA                   None
# 4         RUA                    MARIA LEOPOLDINA                   None
# 5        None                      CICERA GABRIEL                   None
# 6         RUA                EUFRASIO DE OLIVEIRA                   None
# 7         RUA                       CUNHA DA MOTA                   None
# 8         RUA                        SILVA JARDIM                   None
# 9         RUA                                TITA                   None
# 10        RUA        FRANCISCO XAVIER DE OLIVEIRA                   None
# 11        RUA                         JOANA D'ARC                   None
# 12    AVENIDA             ALMIR DE ALMEIDA CASTRO                   None
# 13        RUA                    MACHADO DE ASSIS                   None
# 14        RUA                    FERREIRA ITAJUBA                   None
# 15          R                      JOSÉ MALAQUIAS                   None
# 16        RUA                   ALEXANDRE BARAUNA                   None
# 17        RUA       OLIVACIR RODRIGUES DE FREITAS                   None
# 18       None                   EMILEISA GALILEIA                   None
# 19        RUA                       CUNHA DA MOTA                   None
# 20    AVENIDA                               DUTRA                   None
# 21         AV                    ALBERTO MARANHÃO                   None
# 22       None                                None                   None
# 23         AV                    ALBERTO MARANHÃO                   None
# 24       None                         JUNIORS BAR                   None
# 25        RUA             JOSE LOPES DA FE ARAUJO                   None
# 26        RUA             JOSE FRANCISCO DOS REIS                   None
# 27        RUA                        NILO PECANHA                   None
# 28       None          EMITERIO GAMELEIRA DO REGO                   None
# 29        RUA                     SEIS DE JANEIRO                   None
# ..        ...                                 ...                    ...
# 435       RUA           DOLORES DO CARMO REBOUCAS                   None
# 436       RUA                     RODRIGUES ALVES                   None
# 437      None  PORFESSORA BENIGNA MARTINS MACHADO       ALTO  DA PELONHA
# 438       RUA                      CHIQUINHA MAIA                   None
# 439   AVENIDA           JERONIMO DIX-NEUFT ROSADO                   None
# 440         R            ANTONIO DELMIRO MEDEIROS                   None
# 441      None                       LEAO DE MOURA                   None
# 442   AVENIDA                               DUTRA                   None
# 443       RUA                     HERCULANO COUTO                   None
# 444   AVENIDA                      FRANCISCO MOTA                   None
# 445       RUA                         MELO FRANCO                   None
# 446       RUA             PEDRO LEITE DE OLIVEIRA                   None
# 447   AVENIDA                          RIO BRANCO                   None
# 448   AVENIDA                               DUTRA                   None
# 449       RUA        FRANCISCO CANINDE DOS SANTOS           TRÊS VINTENS
# 450      None           MINISTERIO NOVA JERUSALEM                   None
# 451      None                     EDINAR DE SOUZA                   None
# 452  TRAVESSA                     ANDRE FERNANDES                   None
# 453      None            TRAVESSA ANDRE FERNANDES                   None
# 454       RUA                  MARGARIDA SILVEIRA             ABOLIÇÃO 4
# 455       RUA              RAIMUNDO LEAO DE MOURA                   None
# 456       RUA                     RODRIGUES ALVES                   None
# 457   AVENIDA                      FRANCISCO MOTA                   None
# 458      None  PROFESSORA BENIGNA MARTINS MACHADO       ALTO  DA PELONHA
# 459       RUA                              FARIAS  ALAMÊDA DOS CAJUEIROS
# 460       RUA                   JEVENAL LAMARTINE                   None
# 461       RUA            GENEZIO CAETANO DE SOUZA                   None
# 462      None           SEGUNDA TRAVESSA SAO JOSE                   None
# 463       RUA                      JOAO MARCELINO                   None
# 464      None           FRANCISCO AMARAL DE SOUZA             INTEGRAÇAO
#
#     ESTNUM     CPERS             LOC_COM                    BAIRRO  EMUN  \
# 0     None   2020815                None                      None  None
# 1       70  50984984               : EST             Santo Antônio  None
# 2      619  50984984               : EST            Alto de Sumaré  None
# 3     None   2020815                None            Alto de Sumaré  None
# 4       21  50984984               : EST                 Aeroporto  None
# 5     None   2020815                None                 Aeroporto  None
# 6      690   1231472               : EST         Alto da Conceição  None
# 7      252   1231472               : EST                    Centro  None
# 8      751   1231472               : EST                 Boa Vista  None
# 9       27   2020815               : EST                  Abolição  None
# 10     271   2020815               : EST                  Abolição  None
# 11     116   2020815               : EST             Santa Delmira  None
# 12     103   1231472               : EST                    Centro  None
# 13     340   1231472               : EST                    Centro  None
# 14     630   2020815               : EST             Santo Antônio  None
# 15    None   1231472                None             Santa Delmira  None
# 16     560   2020815               : EST                  Paredões  None
# 17     271   1231472               : EST                 Aeroporto  None
# 18    None   2020815                None        Alto de São Manoel  None
# 19     192   1231472               : EST                    Centro  None
# 20    4502     17603               : EST       ILHA DE SANTA LUZIA  None
# 21     243   1231472                None         Alto da Conceição  None
# 22    None   2020815                None                 Aeroporto  None
# 23    4550   1231472                None                Bom Jardim  None
# 24    None   1231472                None                 Bom Jesus  None
# 25      67   1231472                None             Santo Antônio  None
# 26     244   1231472               : EST                    Pintos  None
# 27    1446   1231472               : EST                Bom Jardim  None
# 28    None   2020815                None        Alto de São Manoel  None
# 29    313B   1231472                None             Santo Antônio  None
# ..     ...       ...                 ...                       ...   ...
# 435    427   2066548               : EST                 Aeroporto  None
# 436    557   2066548               : EST                  Paredões  None
# 437   None   1658204                None                    Rincão  None
# 438    224   2066548               : EST             Santa Delmira  None
# 439    347     17156               : EST                  PAREDÕES  None
# 440   3486  53974237               : EST            Belo Horizonte  None
# 441   None   2066548                None              Nova Betânia  None
# 442   3314   1658204               : EST        Alto de São Manoel  None
# 443    574   2066548               : EST             Santo Antônio  None
# 444   2442   2066548               : EST  Presidente Costa e Silva  None
# 445    883   2066548               : EST                    Centro  None
# 446    310  53974237               : EST       Ilha de Santa Luzia  None
# 447   1909   1658204               : EST                 Doze Anos  None
# 448   2435   1658204               : EST        Alto de São Manoel  None
# 449     17   1658204               : EST                  Abolição  None
# 450   None   2066548                None                  Abolição  None
# 451   None   1658204                None             Santo Antônio  None
# 452    138   2066548               : EST             Santo Antônio  None
# 453    502  53974237               : EST             Santo Antônio  None
# 454    108   1658204   : EST NUMERO 2118                  Abolição  None
# 455    364   1658204               : EST              Nova Betânia  None
# 456   1382   1658204  : EST  NUMERO 4398                Bom Jardim  None
# 457   2875   2066548               : EST  Presidente Costa e Silva  None
# 458   None   1658204                None                    Rincão  None
# 459   1118   1658204               : EST    Planalto Treze de Maio  None
# 460    886   2066548               : EST                Bom Jardim  None
# 461     93   1658204               : EST                    Pintos  None
# 462   None   2066548                None         Alto da Conceição  None
# 463   2233   1658204               : EST                    Centro  None
# 464   None   1658204                None             Santa Delmira  None
#
#         X_CORD      Y_CORD
# 0         0.00        0.00
# 1    681567.66  9430666.36
# 2    685846.05  9421792.96
# 3         0.00        0.00
# 4    681055.93  9425961.19
# 5         0.00        0.00
# 6    682404.47  9424031.95
# 7    683579.02  9425474.03
# 8    682598.52  9425587.01
# 9    683000.63  9427725.00
# 10   681961.85  9429859.24
# 11   681527.97  9430642.74
# 12   684372.76  9425843.83
# 13   684134.83  9425875.91
# 14   683299.28  9426751.70
# 15        0.00        0.00
# 16   684511.07  9426254.28
# 17   680898.39  9426094.76
# 18        0.00        0.00
# 19   683615.09  9425522.14
# 20   684174.70  9424906.57
# 21        0.00        0.00
# 22        0.00        0.00
# 23        0.00        0.00
# 24        0.00        0.00
# 25   683948.45  9429701.49
# 26   688409.62  9424573.36
# 27   684673.45  9427572.08
# 28        0.00        0.00
# 29   683375.59  9426878.91
# ..         ...         ...
# 435  680230.20  9425277.22
# 436  683234.90  9427318.04
# 437       0.00        0.00
# 438  682947.13  9430751.06
# 439  684100.53  9426305.41
# 440       0.00        0.00
# 441       0.00        0.00
# 442  684775.76  9423915.58
# 443  685022.12  9428250.29
# 444  686693.68  9425434.58
# 445  684353.14  9427909.98
# 446  683952.73  9425480.94
# 447  682722.73  9425260.18
# 448  685235.13  9423138.18
# 449  681853.92  9429595.12
# 450       0.00        0.00
# 451       0.00        0.00
# 452  684540.92  9429069.87
# 453       0.00        0.00
# 454  681443.59  9429960.27
# 455  681925.53  9427399.64
# 456  683933.23  9426879.41
# 457  687042.35  9425692.29
# 458       0.00        0.00
# 459  683612.71  9422464.05
# 460  684390.14  9427885.16
# 461  686247.18  9425420.54
# 462       0.00        0.00
# 463  683390.37  9426478.40
# 464       0.00        0.00
#
# [465 rows x 14 columns]

# %%
tbl_evcom['COMM_limpos'] = tbl_evcom['COMM'].apply(lambda x: limpaTexto(x))

tbl_evcom['COMM_nlp'] = tbl_evcom['COMM_limpos'].apply(lambda x: nlp(x))

tbl_evcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 6 columns):
# EID             1605 non-null int64
# CPERS           1605 non-null int64
# COMM            1605 non-null object
# COMM_limpos     1605 non-null object
# COMM_nlp        1605 non-null object
# tamanho_COMM    1605 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 75.3+ KB

# %%
# Acrescentando uma coluna com o número de tokens do campo COMM
tbl_evcom['tamanho_COMM'] = tbl_evcom['COMM_nlp'].apply(lambda x: len(x))

# filtrando as linhas com mais de 15 tokens
tam_com = tbl_evcom[tbl_evcom.tamanho_COMM > 15]

# listando o EID do filtro anterior
lista_eid = tam_com.EID.unique()

print ("Número de registros com mais de 15 tokens           :", len(tam_com))
print ("Número de registros distintos com mais de 15 tokens :", len(lista_eid))
# Out:
# Número de registros com mais de 15 tokens           : 116
# Número de registros distintos com mais de 15 tokens : 101

# %%
#tbl_evcom['tamanho_COMM_limpos_nlp'] = tbl_evcom['COMM_limpos_nlp'].apply(lambda x: len(x))

tbl_evcom.sort_values(by='tamanho_COMM', ascending=0)
# Out:
#           EID     CPERS                                               COMM  \
# 1204  3542806   1658204  PX AO DEPÓSITO DO SACI VIZ AO NUMERO 34 TEM UM...
# 1453  3542861   2020815  O MESMO ENCONTRA-SE AO LADO DA GARAGEM DA EMPR...
# 801   3542691     17820  POR TRÁS DO BAR DE SIENA TEM UM SOBRINHO MAIS ...
# 989   3542750   2020815  INTER INFORMA QUE ACIONOU A VTR NO DIA DE HJ ,...
# 1108  3542778   1658204  PX AO BAR NOVO VISUAL , O CIDADO ESTA EM SUA C...
# 1494  3542870   2066548  EM FRENTE AO PASTEL DO TIO LEO E PROXIMO A IGR...
# 1189  3542801   1658204  O MES INFORMA QUE UM INDIVIDUO COM ARMA DE FOG...
# 960   3542743   2020815  O MESMO SAIU DE SERVIÇO E AO CHEGAR EM CASA TE...
# 18    3542440   1231472  NO ESPETINHO DE MAZÉ NA RUA DO BAR DE SADAN RU...
# 949   3542740   2020815  TEM UM ELEMENTO ARMADO DE RV NO LOCAL, O MESMO...
# 466   3542580   1658204  ARROMBADA E TEM UM PÉ DE CABRA PX A UMA DAS PO...
# 1586  3542894   2066548  PROXIMO A FABRICA DE GESSO E AO VUCO VUCO NUM ...
# 197   3542495   1952021  A vitima aguarda a VTR em frente ao Hotel Pala...
# 414   3542560     13387  UM KADETE VERMELHO COM PLACA DA BAHIA COM SOM ...
# 470   3542582   1658204  PULAR DA MOTO E FUGIR, O MESMO ESTA DE CAMISA ...
# 270   3542513   1954652  DEPOIS DO TEMPERO REGINA, PX AO NUMERAL 116 UM...
# 1103  3542776   2066548  NA ALAMEDA DOS CAJUEIROS POR TRAZ DO BAR DA VI...
# 417   3542561     13387  COMO SE ALGUEM PULOU O SEU MURO, CASA SEM MURO...
# 275   3542514     16355  ACUSADO CONDUZIDO A DP DE PLANTAO, A VITIMA FO...
# 1536  3542882   1658204  DE RV A PÉ, COR DE ROUPA OS DOIS DE BERMUDA UM...
# 420   3542562     18830  MARIDO. A VÍTIMA ESTÁ NA ESQUINA DA RUA, PRÓXI...
# 1265  3542827     16355  CERCA DE 10 KM APOS A BASE PRF, OUVE UM ACIDEN...
# 1051  3542763   1231472  POR TRAZ DO POÇO DA CAERN. UM CARRO ESTÁ COM O...
# 1129  3542785   1658204  PX A MANOEL CONSTRUÇÃO E PX A O BOI NA BRASA, ...
# 79    3542457   1231472  O MESMO DIZ QUE O SOM DO LOCAL ESTÁ EM ALTO VO...
# 1580  3542892   1658204  CONJ. NOVO NO ALTO DA PELONHA 3ª RUA DO CONJ. ...
# 1545  3542884   2066548  SUA CASA FOI ASSALTADA A CASA FICA NA RUA EM F...
# 994   3542751   2020815  O MESMO É VIGILANTE DA ENVIPOL E ESTA COM A VT...
# 1140  3542788   2066548  EM FRENTE AO COLEGIO JOSE NOGUEIRA TEM UM ELEE...
# 105   3542465  30391484  INTER INFORMA QUE TEM UM CARRO TIPO SIENA PRET...
# ...       ...       ...                                                ...
# 589   3542613  30391484                                                  A
# 582   3542611     18830                                              CASA.
# 1448  3542860     17603                                             ROUBAR
# 517   3542592     17156                                           DISPAROS
# 521   3542593  50984984                                           DISPAROS
# 381   3542549     18830                                           DELMIRA.
# 1604  3542898   1658204                                              CASA.
# 1504  3542873   1658204                                     EMBALADOR/////
# 363   3542542     18830                                          VEÍCULOS.
# 202   3542496  65544814                                        FREQUENCIA.
# 953   3542741  65544814                                             MESMA.
# 918   3542730   2022923                                             CLUBE.
# 1327  3542839     17603                                             LOCAL.
# 896   3542722     17820                                           QUIEROZ.
# 880   3542717   2022923                                         INTEGRAÇÃO
# 276   3542514     16355                                            VEICULO
# 278   3542515  65544814                                        RESIDENCIA.
# 1344  3542841     17603                                            GENÉSIO
# 282   3542516   1954652                                        AUXILIADORA
# 870   3542712   2022923                                           NASCIDO.
# 301   3542523     16355                                            PASSADA
# 865   3542711     17820                                        INTERSSADO.
# 1358  3542844   1231472                                                 3.
# 815   3542695   2022923                                           MOMENTO.
# 340   3542534     18830                                          PRÍNCIPE.
# 1511  3542874  53974237                                             DOENTE
# 358   3542540     18830                                         CARNAUBAL.
# 771   3542679   1954652                                            SOSSEGO
# 1302  3542833     17603                                                  .
# 176   3542489   1952021                                                  ]
#
#                                             COMM_limpos  \
# 1204  px ao deposito do saci viz ao numero 34 tem um...
# 1453  o mesmo encontra se ao lado da garagem da empr...
# 801   por tras do bar de siena tem um sobrinho mais ...
# 989   inter informa que acionou a vtr no dia de hj a...
# 1108  px ao bar novo visual o cidado esta em sua cas...
# 1494  em frente ao pastel do tio leo e proximo a igr...
# 1189  o mes informa que um individuo com arma de fog...
# 960   o mesmo saiu de servico e ao chegar em casa te...
# 18    no espetinho de maze na rua do bar de sadan ru...
# 949   tem um elemento armado de rv no local o mesmo ...
# 466   arrombada e tem um pe de cabra px a uma das po...
# 1586  proximo a fabrica de gesso e ao vuco vuco num ...
# 197   a vitima aguarda a vtr em frente ao hotel pala...
# 414   um kadete vermelho com placa da bahia com som ...
# 470   pular da moto e fugir o mesmo esta de camisa b...
# 270   depois do tempero regina px ao numeral 116 um ...
# 1103  na alameda dos cajueiros por traz do bar da vi...
# 417   como se alguem pulou o seu muro casa sem muro ...
# 275   acusado conduzido a dp de plantao a vitima foi...
# 1536  de rv a pe cor de roupa os dois de bermuda um ...
# 420   marido a vitima esta na esquina da rua proximo...
# 1265  cerca de 10 km apos a base prf ouve um acident...
# 1051  por traz do poco da caern um carro esta com o ...
# 1129  px a manoel construcao e px a o boi na brasa a...
# 79    o mesmo diz que o som do local esta em alto vo...
# 1580  conj novo no alto da pelonha 3a rua do conj px...
# 1545  sua casa foi assaltada a casa fica na rua em f...
# 994   o mesmo e vigilante da envipol e esta com a vt...
# 1140  em frente ao colegio jose nogueira tem um elee...
# 105   inter informa que tem um carro tipo siena pret...
# ...                                                 ...
# 589                                                   a
# 582                                                casa
# 1448                                             roubar
# 517                                            disparos
# 521                                            disparos
# 381                                             delmira
# 1604                                               casa
# 1504                                          embalador
# 363                                            veiculos
# 202                                          frequencia
# 953                                               mesma
# 918                                               clube
# 1327                                              local
# 896                                             quieroz
# 880                                          integracao
# 276                                             veiculo
# 278                                          residencia
# 1344                                            genesio
# 282                                         auxiliadora
# 870                                             nascido
# 301                                             passada
# 865                                          interssado
# 1358                                                  3
# 815                                             momento
# 340                                            principe
# 1511                                             doente
# 358                                           carnaubal
# 771                                             sossego
# 1302
# 176
#
#                                                COMM_nlp  tamanho_COMM
# 1204  (px, a, o, deposito, do, saci, viz, a, o, nume...            19
# 1453  (o, mesmo, encontra, se, a, o, lado, da, garag...            19
# 801   (por, tras, do, bar, de, siena, tem, um, sobri...            19
# 989   (inter, informa, que, acionou, a, vtr, no, dia...            19
# 1108  (px, a, o, bar, novo, visual, o, cidado, esta,...            19
# 1494  (em, frente, a, o, pastel, do, tio, leo, e, pr...            19
# 1189  (o, mes, informa, que, um, individuo, com, arm...            18
# 960   (o, mesmo, saiu, de, servico, e, a, o, chegar,...            18
# 18    (no, espetinho, de, maze, na, rua, do, bar, de...            18
# 949   (tem, um, elemento, armado, de, rv, no, local,...            18
# 466   (arrombada, e, tem, um, pe, de, cabra, px, a, ...            18
# 1586  (proximo, a, fabrica, de, gesso, e, a, o, vuco...            18
# 197   (a, vitima, aguarda, a, vtr, em, frente, a, o,...            18
# 414   (um, kadete, vermelho, com, placa, da, bahia, ...            17
# 470   (pular, da, moto, e, fugir, o, mesmo, esta, de...            17
# 270   (depois, do, tempero, regina, px, a, o, numera...            17
# 1103  (na, alameda, dos, cajueiros, por, traz, do, b...            17
# 417   (como, se, alguem, pulou, o, seu, muro, casa, ...            17
# 275   (acusado, conduzido, a, dp, de, plantao, a, vi...            17
# 1536  (de, rv, a, pe, cor, de, roupa, os, dois, de, ...            17
# 420   (marido, a, vitima, esta, na, esquina, da, rua...            17
# 1265  (cerca, de, 10, km, apos, a, base, prf, ouve, ...            17
# 1051  (por, traz, do, poco, da, caern, um, carro, es...            17
# 1129  (px, a, manoel, construcao, e, px, a, o, boi, ...            17
# 79    (o, mesmo, diz, que, o, som, do, local, esta, ...            17
# 1580  (conj, novo, no, alto, da, pelonha, 3a, rua, d...            17
# 1545  (sua, casa, foi, assaltada, a, casa, fica, na,...            17
# 994   (o, mesmo, e, vigilante, da, envipol, e, esta,...            17
# 1140  (em, frente, a, o, colegio, jose, nogueira, te...            17
# 105   (inter, informa, que, tem, um, carro, tipo, si...            17
# ...                                                 ...           ...
# 589                                                 (a)             1
# 582                                              (casa)             1
# 1448                                           (roubar)             1
# 517                                          (disparos)             1
# 521                                          (disparos)             1
# 381                                           (delmira)             1
# 1604                                             (casa)             1
# 1504                                        (embalador)             1
# 363                                          (veiculos)             1
# 202                                        (frequencia)             1
# 953                                             (mesma)             1
# 918                                             (clube)             1
# 1327                                            (local)             1
# 896                                           (quieroz)             1
# 880                                        (integracao)             1
# 276                                           (veiculo)             1
# 278                                        (residencia)             1
# 1344                                          (genesio)             1
# 282                                       (auxiliadora)             1
# 870                                           (nascido)             1
# 301                                           (passada)             1
# 865                                        (interssado)             1
# 1358                                                (3)             1
# 815                                           (momento)             1
# 340                                          (principe)             1
# 1511                                           (doente)             1
# 358                                         (carnaubal)             1
# 771                                           (sossego)             1
# 1302                                                 ()             0
# 176                                                  ()             0
#
# [1605 rows x 6 columns]

# %%
# Cada ocorrência fica espalhada em vários linhas da tabela EVCOM. Com a lista
# dos EIDs com mais tokens, vou montar uma consulta pra retornar todas as linhas
# que compõem o registro completo, pra garantir que usaremos o histórico completo
# das ocorrências.

# criando string com os EIDs
lista = str(lista_eid.tolist())
lista = lista[1:-1]

# Montando a query

# Registros de EVCOM entre 23 e 26 de dezembro de 2012 com maior
# número de tokens numa mesma linha
sql_evcom_lista = "select eid, cpers, comm from evcom where eid in ("
sql_evcom_lista += lista
sql_evcom_lista += ") order by eid, cdts, lin_grp, lin_ord"

print(sql_evcom_lista)
# Out:
# select eid, cpers, comm from evcom where eid in (3542440, 3542443, 3542445, 3542447, 3542450, 3542457, 3542459, 3542465, 3542466, 3542481, 3542487, 3542490, 3542495, 3542506, 3542513, 3542514, 3542525, 3542530, 3542544, 3542546, 3542547, 3542549, 3542554, 3542556, 3542560, 3542561, 3542562, 3542566, 3542568, 3542580, 3542582, 3542588, 3542598, 3542605, 3542609, 3542611, 3542612, 3542617, 3542629, 3542637, 3542639, 3542653, 3542681, 3542691, 3542693, 3542720, 3542731, 3542740, 3542743, 3542749, 3542750, 3542751, 3542755, 3542757, 3542761, 3542763, 3542768, 3542776, 3542778, 3542785, 3542788, 3542793, 3542795, 3542798, 3542800, 3542801, 3542802, 3542805, 3542806, 3542808, 3542815, 3542819, 3542825, 3542827, 3542828, 3542838, 3542841, 3542844, 3542851, 3542853, 3542854, 3542855, 3542857, 3542861, 3542864, 3542867, 3542868, 3542870, 3542872, 3542879, 3542882, 3542884, 3542885, 3542886, 3542891, 3542892, 3542894, 3542895, 3542896, 3542897, 3542898) order by eid, cdts, lin_grp, lin_ord

# %%
connection = cx_Oracle.connect("MOSSORO", "MOSSORO", "10.0.0.7/cad80.world", encoding = "UTF-8", nencoding = "UTF-8")

tbl_evcom2 = pd.read_sql(sql_evcom_lista, connection)

connection.close()


tbl_evcom2.head(20)
# Out:
#         EID    CPERS                                               COMM
# 0   3542440  1231472  NO ESPETINHO DE MAZÉ NA RUA DO BAR DE SADAN RU...
# 1   3542440  1231472             ALTO VOLUME TIRANDO O SOSSEGO DO MESMO
# 2   3542443  2020815  O SOLICITANTE DIZ QUE DE FRENTE AO EXTRA HÁ UM...
# 3   3542443  2020815                                             CARRO.
# 4   3542443  2020815                OS POPULARES ESTÃO ESPERANDO A VTR.
# 5   3542443  2020815             O SOLICITANTE DIZ QUE JÁ HAVIA LIGADO.
# 6   3542443  2020815                         A O.C. FICA NA ABOLIÇÃO I.
# 7   3542445  2020815                                         CASA 2233.
# 8   3542445  2020815  PX AO ANTIGO CERCADO BAR E A IGREJA UNIVERSAL ...
# 9   3542445  2020815                                        RESIDENCIA.
# 10  3542447  1231472          A RUA DA SOLICITANTE É ALMEIDA CASTRO 582
# 11  3542447  1231472  A INTER. INFORMA QUE NA RUA POR TRAZ DE SUA RE...
# 12  3542447  1231472                        TIRANDO O SOSSEGO DA MESMA.
# 13  3542450  2020815               CASA 174 PX AO SALÃO CORES E CORTES.
# 14  3542450  2020815  O SOLICITANTE DIZ QUE SE SEPAROU DE SUA ESPOSA...
# 15  3542450  2020815        E BATENDO EM SUA PORTA. NÃO O DEIXA DORMIR.
# 16  3542450  2020815  A VÍTIMA GOSTARIA QUE UMA VTR FOSSE AO LOCAL P...
# 17  3542450  2020815                                         TENTATIVA.
# 18  3542450    17603  uma mulher quebrou a porta da residencia mas o...
# 19  3542450    17603                  ele disse que estava tudo normal.

# %%
tbl_evcom2['COMM_limpo'] = tbl_evcom2['COMM'].apply(lambda x: limpaTexto(x))

tbl_evcom2.head(20)
# Out:
#        EID    CPERS                                               COMM  \
# 0  3542440  1231472  NO ESPETINHO DE MAZÉ NA RUA DO BAR DE SADAN RU...
# 1  3542440  1231472             ALTO VOLUME TIRANDO O SOSSEGO DO MESMO
# 2  3542443  2020815  O SOLICITANTE DIZ QUE DE FRENTE AO EXTRA HÁ UM...
# 3  3542443  2020815                                             CARRO.
# 4  3542443  2020815                OS POPULARES ESTÃO ESPERANDO A VTR.
#
#                                           COMM_limpo
# 0  no espetinho de maze na rua do bar de sadan ru...
# 1             alto volume tirando o sossego do mesmo
# 2  o solicitante diz que de frente ao extra ha um...
# 3                                              carro
# 4                 os populares estao esperando a vtr

# %%
# Aplicando SpaCy nos registros limpos
tbl_evcom2['COMM_nlp'] = tbl_evcom2['COMM_limpo'].apply(lambda x: nlp(x))

tbl_evcom2.head(20)
# Out:
#        EID    CPERS                                               COMM  \
# 0  3542440  1231472  NO ESPETINHO DE MAZÉ NA RUA DO BAR DE SADAN RU...
# 1  3542440  1231472             ALTO VOLUME TIRANDO O SOSSEGO DO MESMO
# 2  3542443  2020815  O SOLICITANTE DIZ QUE DE FRENTE AO EXTRA HÁ UM...
# 3  3542443  2020815                                             CARRO.
# 4  3542443  2020815                OS POPULARES ESTÃO ESPERANDO A VTR.
#
#                                           COMM_limpo  \
# 0  no espetinho de maze na rua do bar de sadan ru...
# 1             alto volume tirando o sossego do mesmo
# 2  o solicitante diz que de frente ao extra ha um...
# 3                                              carro
# 4                 os populares estao esperando a vtr
#
#                                             COMM_nlp
# 0  (no, espetinho, de, maze, na, rua, do, bar, de...
# 1     (alto, volume, tirando, o, sossego, do, mesmo)
# 2  (o, solicitante, diz, que, de, frente, a, o, e...
# 3                                            (carro)
# 4          (os, populares, estao, esperando, a, vtr)

# %%
tbl_evcom2.info()
#tbl_evcom2.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 5 columns):
# EID           383 non-null int64
# CPERS         383 non-null int64
# COMM          383 non-null object
# COMM_limpo    383 non-null object
# COMM_nlp      383 non-null object
# dtypes: int64(2), object(3)
# memory usage: 15.0+ KB

# %%
tbl_evcom2['COMM_nlp'].apply(lambda x: tokenPosLemma(x))
# Out:
# no espetinho de maze na rua do bar de sadan russein um carro esta com o som em
# A string contem o seguinte número de tokens:  18
#
# original          : no
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : espetinho
# lemma             : espeto
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : maze
# lemma             : maze
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : rua
# lemma             : ruir
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : bar
# lemma             : bar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : sadan
# lemma             : sadan
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : russein
# lemma             : russein
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : carro
# lemma             : carro
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : esta
# lemma             : este
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : com
# lemma             : com
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : som
# lemma             : som
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# ==================================================================
# alto volume tirando o sossego do mesmo
# A string contem o seguinte número de tokens:  7
#
# original          : alto
# lemma             : alto
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : volume
# lemma             : volumar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : tirando
# lemma             : tirar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : sossego
# lemma             : sossegar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : DET ( determiner )
# ----------------------------------------
# ==================================================================
# o solicitante diz que de frente ao extra ha um elemento amarrado dentro de um
# A string contem o seguinte número de tokens:  16
#
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : solicitante
# lemma             : solicitante
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : diz
# lemma             : dizer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : frente
# lemma             : frente
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : extra
# lemma             : extra
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : ha
# lemma             : ha
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : elemento
# lemma             : elemento
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : amarrado
# lemma             : amarrar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : dentro
# lemma             : dentro
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# ==================================================================
# carro
# A string contem o seguinte número de tokens:  1
#
# original          : carro
# lemma             : carro
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# os populares estao esperando a vtr
# A string contem o seguinte número de tokens:  6
#
# original          : os
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : populares
# lemma             : popular
# POS tag           : SYM ( symbol )
# ----------------------------------------
# original          : estao
# lemma             : estao
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : esperando
# lemma             : esperar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : vtr
# lemma             : vtr
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# o solicitante diz que ja havia ligado
# A string contem o seguinte número de tokens:  7
#
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : solicitante
# lemma             : solicitante
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : diz
# lemma             : dizer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : ja
# lemma             : ja
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : havia
# lemma             : haver
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : ligado
# lemma             : ligar
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# a o c fica na abolicao i
# A string contem o seguinte número de tokens:  7
#
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : c
# lemma             : c
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : fica
# lemma             : ficar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : abolicao
# lemma             : abolicao
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : i
# lemma             : ir
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# ==================================================================
# casa 2233
# A string contem o seguinte número de tokens:  2
#
# original          : casa
# lemma             : casar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : 2233
# lemma             : 2233
# POS tag           : PROPN ( proper noun )
# ----------------------------------------
# ==================================================================
# px ao antigo cercado bar e a igreja universal ha um som muito alto numa
# A string contem o seguinte número de tokens:  16
#
# original          : px
# lemma             : px
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : antigo
# lemma             : antigo
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : cercado
# lemma             : cercar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : bar
# lemma             : bar
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : igreja
# lemma             : igreja
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : universal
# lemma             : universal
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : ha
# lemma             : ha
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : som
# lemma             : som
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : muito
# lemma             : muito
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : alto
# lemma             : alto
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : numa
# lemma             : numa
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# residencia
# A string contem o seguinte número de tokens:  1
#
# original          : residencia
# lemma             : residencia
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# a rua da solicitante e almeida castro 582
# A string contem o seguinte número de tokens:  8
#
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : rua
# lemma             : ruir
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : solicitante
# lemma             : solicitante
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : almeida
# lemma             : almeida
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : castro
# lemma             : castrar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : 582
# lemma             : 582
# POS tag           : NUM ( numeral )
# ----------------------------------------
# ==================================================================
# a inter informa que na rua por traz de sua residencia ha um som em alto volume
# A string contem o seguinte número de tokens:  17
#
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : inter
# lemma             : inter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : rua
# lemma             : ruir
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : por
# lemma             : por
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : traz
# lemma             : trazer
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : sua
# lemma             : suar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : residencia
# lemma             : residencia
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : ha
# lemma             : ha
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : som
# lemma             : som
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : alto
# lemma             : alto
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : volume
# lemma             : volumar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# tirando o sossego da mesma
# A string contem o seguinte número de tokens:  5
#
# original          : tirando
# lemma             : tirar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : sossego
# lemma             : sossegar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : mesma
# lemma             : mesmo
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# casa 174 px ao salao cores e cortes
# A string contem o seguinte número de tokens:  9
#
# original          : casa
# lemma             : casar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : 174
# lemma             : 174
# POS tag           : NUM ( numeral )
# ----------------------------------------
# original          : px
# lemma             : px
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : salao
# lemma             : salao
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : cores
# lemma             : corar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : cortes
# lemma             : corte
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# o solicitante diz que se separou de sua esposa e ela esta neste momento gritando
# A string contem o seguinte número de tokens:  16
#
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : solicitante
# lemma             : solicitante
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : diz
# lemma             : dizer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : se
# lemma             : se
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : separou
# lemma             : separar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : sua
# lemma             : suar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : esposa
# lemma             : esposo
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : ela
# lemma             : ele
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : esta
# lemma             : este
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : n
# lemma             : n
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : este
# lemma             : este
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : momento
# lemma             : momento
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : gritando
# lemma             : gritar
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# e batendo em sua porta nao o deixa dormir
# A string contem o seguinte número de tokens:  9
#
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : batendo
# lemma             : bater
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : sua
# lemma             : suar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : porta
# lemma             : portar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : nao
# lemma             : nao
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : deixa
# lemma             : deixar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : dormir
# lemma             : dormir
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# a vitima gostaria que uma vtr fosse ao local para resolver esse problema
# A string contem o seguinte número de tokens:  14
#
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : vitima
# lemma             : vitimar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : gostaria
# lemma             : gostar
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : uma
# lemma             : umar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : vtr
# lemma             : vtr
# POS tag           : AUX ( auxiliary )
# ----------------------------------------
# original          : fosse
# lemma             : ser
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : local
# lemma             : local
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : para
# lemma             : parir
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : resolver
# lemma             : resolver
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : esse
# lemma             : esse
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : problema
# lemma             : problema
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# tentativa
# A string contem o seguinte número de tokens:  1
#
# original          : tentativa
# lemma             : tentativo
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# uma mulher quebrou a porta da residencia mas o interessado nao quiz representar
# A string contem o seguinte número de tokens:  13
#
# original          : uma
# lemma             : umar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mulher
# lemma             : mulher
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : quebrou
# lemma             : quebrar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : porta
# lemma             : portar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : residencia
# lemma             : residencia
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : mas
# lemma             : mas
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : interessado
# lemma             : interessar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : nao
# lemma             : nao
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : quiz
# lemma             : quiz
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : representar
# lemma             : representar
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# ele disse que estava tudo normal
# A string contem o seguinte número de tokens:  6
#
# original          : ele
# lemma             : ele
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : disse
# lemma             : dizer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : estava
# lemma             : estar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : tudo
# lemma             : tudo
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : normal
# lemma             : normal
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# ==================================================================
# em frente a stock frios
# A string contem o seguinte número de tokens:  5
#
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : frente
# lemma             : frente
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : stock
# lemma             : stock
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : frios
# lemma             : frio
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# ==================================================================
# o mesmo diz que o som do local esta em alto volume tirando o sossego do mesmo
# A string contem o seguinte número de tokens:  17
#
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : diz
# lemma             : dizer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : som
# lemma             : som
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : local
# lemma             : local
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : esta
# lemma             : este
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : alto
# lemma             : alto
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : volume
# lemma             : volumar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : tirando
# lemma             : tirar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : sossego
# lemma             : sossegar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : DET ( determiner )
# ----------------------------------------
# ==================================================================
# prox ao colegio das irmas e na rua de frente ao bar da cajarana
# A string contem o seguinte número de tokens:  16
#
# original          : prox
# lemma             : prox
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : colegio
# lemma             : colegio
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : das
# lemma             : das
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : irmas
# lemma             : irmas
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : rua
# lemma             : ruir
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : frente
# lemma             : frente
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : bar
# lemma             : bar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : cajarana
# lemma             : cajarana
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# um individuo de camisa amarela e bermuda esta em atitude suspeita chamando em
# A string contem o seguinte número de tokens:  13
#
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : individuo
# lemma             : individuar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : camisa
# lemma             : camisa
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : amarela
# lemma             : amarelo
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : bermuda
# lemma             : bermuda
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : esta
# lemma             : este
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : atitude
# lemma             : atitude
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : suspeita
# lemma             : suspeito
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : chamando
# lemma             : chamar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# ==================================================================
# frente a residencia
# A string contem o seguinte número de tokens:  3
#
# original          : frente
# lemma             : frente
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : residencia
# lemma             : residencia
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# inter solicita
# A string contem o seguinte número de tokens:  2
#
# original          : inter
# lemma             : inter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : solicita
# lemma             : solicitar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# inter informa que tem um carro tipo siena preto com o som do carro muito alto em
# A string contem o seguinte número de tokens:  17
#
# original          : inter
# lemma             : inter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : tem
# lemma             : ter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : carro
# lemma             : carro
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : tipo
# lemma             : tipo
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : siena
# lemma             : siena
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : preto
# lemma             : preto
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : com
# lemma             : com
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : som
# lemma             : som
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : carro
# lemma             : carro
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : muito
# lemma             : muito
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : alto
# lemma             : alto
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# ==================================================================
# frente ao bar da panelada px ao sindicato da construcao civil
# A string contem o seguinte número de tokens:  13
#
# original          : frente
# lemma             : frente
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : bar
# lemma             : bar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : panelada
# lemma             : panelada
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : px
# lemma             : px
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : sindicato
# lemma             : sindicato
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : construcao
# lemma             : construcao
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : civil
# lemma             : civil
# POS tag           : X ( other )
# ----------------------------------------
# ==================================================================
# no vuco vuco o mesmo informa que vendeu um ventilador a um senhor e o mesmo
# A string contem o seguinte número de tokens:  16
#
# original          : no
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : vuco
# lemma             : vuco
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : vuco
# lemma             : vuco
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : vendeu
# lemma             : vender
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : ventilador
# lemma             : ventilador
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : um
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : senhor
# lemma             : senhor
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# ==================================================================
# chegou hoje ameacando o mesmo inter pede a presenca da vtr no local
# A string contem o seguinte número de tokens:  13
#
# original          : chegou
# lemma             : chegar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : hoje
# lemma             : hoje
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : ameacando
# lemma             : ameacando
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : inter
# lemma             : inter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : pede
# lemma             : pedir
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : presenca
# lemma             : presenca
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : vtr
# lemma             : vtr
# POS tag           : X ( other )
# ----------------------------------------
# original          : no
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : local
# lemma             : local
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# inter informa que tem uns 10 rapazes uns de menor e outros ja de maior fumando
# A string contem o seguinte número de tokens:  16
#
# original          : inter
# lemma             : inter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : tem
# lemma             : ter
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : uns
# lemma             : um
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : 10
# lemma             : 10
# POS tag           : NUM ( numeral )
# ----------------------------------------
# original          : rapazes
# lemma             : rapaz
# POS tag           : SYM ( symbol )
# ----------------------------------------
# original          : uns
# lemma             : um
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : menor
# lemma             : menor
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : outros
# lemma             : outro
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : ja
# lemma             : ja
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : maior
# lemma             : maior
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : fumando
# lemma             : fumar
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# maconha pixando os muros e fazendo bagunca na referida rua
# A string contem o seguinte número de tokens:  10
#
# original          : maconha
# lemma             : maconha
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : pixando
# lemma             : pixando
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : os
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : muros
# lemma             : muro
# POS tag           : SYM ( symbol )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : fazendo
# lemma             : fazer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : bagunca
# lemma             : bagunca
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : referida
# lemma             : referir
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : rua
# lemma             : ruir
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# fica ao lado da fundac px supermercado queiroz
# A string contem o seguinte número de tokens:  9
#
# original          : fica
# lemma             : ficar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : lado
# lemma             : lado
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : fundac
# lemma             : fundac
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : px
# lemma             : px
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : supermercado
# lemma             : supermercado
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : queiroz
# lemma             : queiroz
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# estao px ao numero da residencia 357
# A string contem o seguinte número de tokens:  8
#
# original          : estao
# lemma             : estao
# POS tag           : VERB ( verb )
# ...
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : tentando
# lemma             : tentar
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# fuarr seu esposo
# A string contem o seguinte número de tokens:  3
#
# original          : fuarr
# lemma             : fuarr
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : seu
# lemma             : seu
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : esposo
# lemma             : esposar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# golf branco oju 5340 grossos rn toca cd pionner e sua carteira de cedulas com
# A string contem o seguinte número de tokens:  15
#
# original          : golf
# lemma             : golf
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : branco
# lemma             : branco
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : oju
# lemma             : oju
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : 5340
# lemma             : 5340
# POS tag           : NUM ( numeral )
# ----------------------------------------
# original          : grossos
# lemma             : grosso
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : rn
# lemma             : rn
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : toca
# lemma             : tocar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : cd
# lemma             : cd
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : pionner
# lemma             : pionner
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : sua
# lemma             : suar
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : carteira
# lemma             : carteiro
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : cedulas
# lemma             : cedulas
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : com
# lemma             : com
# POS tag           : ADP ( adposition )
# ----------------------------------------
# ==================================================================
# todos documentos
# A string contem o seguinte número de tokens:  2
#
# original          : todos
# lemma             : todo
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : documentos
# lemma             : documento
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# o mesmo informa que arrombaram a fechadura da porta de seu veiculo aqui
# A string contem o seguinte número de tokens:  13
#
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesmo
# lemma             : mesmo
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : arrombaram
# lemma             : arrombar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : fechadura
# lemma             : fechadura
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : porta
# lemma             : portar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : seu
# lemma             : seu
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : veiculo
# lemma             : veicular
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : aqui
# lemma             : aqui
# POS tag           : ADV ( adverb )
# ----------------------------------------
# ==================================================================
# especificado e subtraindo os pertences aqui especificados a vitima foi
# A string contem o seguinte número de tokens:  10
#
# original          : especificado
# lemma             : especificar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : subtraindo
# lemma             : subtrair
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : os
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : pertences
# lemma             : pertencer
# POS tag           : SYM ( symbol )
# ----------------------------------------
# original          : aqui
# lemma             : aqui
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : especificados
# lemma             : especificar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : vitima
# lemma             : vitimar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : foi
# lemma             : ser
# POS tag           : VERB ( verb )
# ----------------------------------------
# ==================================================================
# orientada a prestar queixa na dp de plantao o acontecido foi em frente ao clube
# A string contem o seguinte número de tokens:  16
#
# original          : orientada
# lemma             : orientar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : prestar
# lemma             : prestar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : queixa
# lemma             : queixar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : dp
# lemma             : dp
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : plantao
# lemma             : plantao
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : acontecido
# lemma             : acontecer
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : foi
# lemma             : ser
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : frente
# lemma             : frente
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : o
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : clube
# lemma             : clube
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# nassau
# A string contem o seguinte número de tokens:  1
#
# original          : nassau
# lemma             : nassau
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# chegando no corredor na av integracao passando do bar da viuva chegando no
# A string contem o seguinte número de tokens:  13
#
# original          : chegando
# lemma             : chegar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : no
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : corredor
# lemma             : corredor
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : na
# lemma             : o
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : av
# lemma             : av
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : integracao
# lemma             : integracao
# POS tag           : ADJ ( adjective )
# ----------------------------------------
# original          : passando
# lemma             : passar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : do
# lemma             : do
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : bar
# lemma             : bar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : da
# lemma             : da
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : viuva
# lemma             : viuvar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : chegando
# lemma             : chegar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : no
# lemma             : o
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# ==================================================================
# orelhao primeira a direita e depois primeira a direita novamente
# A string contem o seguinte número de tokens:  10
#
# original          : orelhao
# lemma             : orelhao
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : primeira
# lemma             : primeiro
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : direita
# lemma             : direito
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : depois
# lemma             : depois
# POS tag           : ADV ( adverb )
# ----------------------------------------
# original          : primeira
# lemma             : primeiro
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : direita
# lemma             : direito
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : novamente
# lemma             : novamente
# POS tag           : ADV ( adverb )
# ----------------------------------------
# ==================================================================
# a mesma informa que esta so em casa e estao forcando a porta de tras de sua
# A string contem o seguinte número de tokens:  17
#
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : mesma
# lemma             : mesmo
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : informa
# lemma             : informar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : que
# lemma             : que
# POS tag           : SCONJ ( subordinating conjunction )
# ----------------------------------------
# original          : esta
# lemma             : este
# POS tag           : PRON ( pronoun )
# ----------------------------------------
# original          : so
# lemma             : so
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : em
# lemma             : em
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : casa
# lemma             : casar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : e
# lemma             : e
# POS tag           : CCONJ ( coordinating conjunction )
# ----------------------------------------
# original          : estao
# lemma             : estao
# POS tag           : AUX ( auxiliary )
# ----------------------------------------
# original          : forcando
# lemma             : forcar
# POS tag           : VERB ( verb )
# ----------------------------------------
# original          : a
# lemma             : o
# POS tag           : DET ( determiner )
# ----------------------------------------
# original          : porta
# lemma             : portar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : tras
# lemma             : tras
# POS tag           : NOUN ( noun )
# ----------------------------------------
# original          : de
# lemma             : de
# POS tag           : ADP ( adposition )
# ----------------------------------------
# original          : sua
# lemma             : suar
# POS tag           : DET ( determiner )
# ----------------------------------------
# ==================================================================
# casa
# A string contem o seguinte número de tokens:  1
#
# original          : casa
# lemma             : casar
# POS tag           : NOUN ( noun )
# ----------------------------------------
# ==================================================================
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 353    None
# 354    None
# 355    None
# 356    None
# 357    None
# 358    None
# 359    None
# 360    None
# 361    None
# 362    None
# 363    None
# 364    None
# 365    None
# 366    None
# 367    None
# 368    None
# 369    None
# 370    None
# 371    None
# 372    None
# 373    None
# 374    None
# 375    None
# 376    None
# 377    None
# 378    None
# 379    None
# 380    None
# 381    None
# 382    None
# Name: COMM_nlp, Length: 383, dtype: object

# %%
tbl_evcom2['COMM_nlp'].to_csv("evcom_2012dez23a26-nlp.txt")
